# %%
# Install library yang diperlukan
# !pip install opencv-python matplotlib seaborn

import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
from google.colab import files
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from IPython.display import display, HTML
import io
from PIL import Image

print("Library berhasil diinstall dan diimport")
# Out:
# ...
# Library berhasil diinstall dan diimport

# %%
# Membuat struktur folder untuk menyimpan gambar
os.makedirs('handwritten_digits/0', exist_ok=True)
os.makedirs('handwritten_digits/3', exist_ok=True)
os.makedirs('handwritten_digits/7', exist_ok=True)

print("Struktur folder berhasil dibuat:")
print("handwritten_digits/")
print("├── 0/")
print("├── 1/")
print("└── 9/")
# Out:
# Struktur folder berhasil dibuat:
# handwritten_digits/
# ├── 0/
# ├── 1/
# └── 9/

# %%
print("=== UPLOAD GAMBAR UNTUK DIGIT 0 ===")
print("Silakan upload 10 gambar untuk digit 0")

# List untuk menyimpan nama file yang diupload
uploaded_files_0 = []

for i in range(10):
    print(f"\nUpload gambar ke-{i+1} untuk digit 0:")
    uploaded = files.upload()

    # Dapatkan nama file yang diupload
    filename = list(uploaded.keys())[0]

    # Pindahkan file ke folder digit 0
    os.rename(filename, f'handwritten_digits/0/digit0_{i+1}.png')
    uploaded_files_0.append(f'digit0_{i+1}.png')

    print(f"Gambar {filename} berhasil disimpan sebagai digit0_{i+1}.png")

print(f"\nTotal {len(uploaded_files_0)} gambar digit 0 berhasil diupload")
# Out:
# === UPLOAD GAMBAR UNTUK DIGIT 0 ===
# Silakan upload 10 gambar untuk digit 0
#
# Upload gambar ke-1 untuk digit 0:
#      <input type="file" id="files-bb9b7a2c-da7a-47e4-a83c-b666d4a265b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb9b7a2c-da7a-47e4-a83c-b666d4a265b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
print("=== UPLOAD GAMBAR UNTUK DIGIT 1 ===")
print("Silakan upload 10 gambar untuk digit 1")

uploaded_files_1 = []

for i in range(10):
    print(f"\nUpload gambar ke-{i+1} untuk digit 1:")
    uploaded = files.upload()

    # Dapatkan nama file yang diupload
    filename = list(uploaded.keys())[0]

    # Pindahkan file ke folder digit 1
    os.rename(filename, f'handwritten_digits/1/digit1_{i+1}.png')
    uploaded_files_1.append(f'digit3_{i+1}.png')

    print(f"Gambar {filename} berhasil disimpan sebagai digit1_{i+1}.png")

print(f"\nTotal {len(uploaded_files_1)} gambar digit 1 berhasil diupload")
# Out:
# === UPLOAD GAMBAR UNTUK DIGIT 1 ===
# Silakan upload 10 gambar untuk digit 1
#
# Upload gambar ke-1 untuk digit 1:
#      <input type="file" id="files-6769f917-e34b-476d-bf6f-619b1eb90aea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6769f917-e34b-476d-bf6f-619b1eb90aea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
print("=== UPLOAD GAMBAR UNTUK DIGIT 9 ===")
print("Silakan upload 10 gambar untuk digit 9")

uploaded_files_9 = []

for i in range(10):
    print(f"\nUpload gambar ke-{i+1} untuk digit 9:")
    uploaded = files.upload()

    # Dapatkan nama file yang diupload
    filename = list(uploaded.keys())[0]

    # Pindahkan file ke folder digit 9
    os.rename(filename, f'handwritten_digits/9/digit9_{i+1}.png')
    uploaded_files_9.append(f'digit9_{i+1}.png')

    print(f"Gambar {filename} berhasil disimpan sebagai digit9_{i+1}.png")

print(f"\nTotal {len(uploaded_files_9)} gambar digit 9 berhasil diupload")
# Out:
# === UPLOAD GAMBAR UNTUK DIGIT 9 ===
# Silakan upload 10 gambar untuk digit 9
#
# Upload gambar ke-1 untuk digit 9:
#      <input type="file" id="files-cc1d481f-ff99-4335-96bc-6cef90fd4fd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc1d481f-ff99-4335-96bc-6cef90fd4fd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %%
print("=== VERIFIKASI FILE YANG DIUPLOAD ===")

base_dir = 'handwritten_digits'
total_files = 0

for digit in ['0', '1', '9']:
    digit_dir = os.path.join(base_dir, digit)
    files_in_dir = os.listdir(digit_dir)
    print(f"Digit {digit}: {len(files_in_dir)} file")
    total_files += len(files_in_dir)

print(f"\nTotal semua file: {total_files} file")
print("Upload selesai! Melanjutkan ke pra-pemrosesan...")
# Out:
# === VERIFIKASI FILE YANG DIUPLOAD ===
# Digit 0: 10 file
# Digit 1: 10 file
# Digit 9: 10 file
#
# Total semua file: 30 file
# Upload selesai! Melanjutkan ke pra-pemrosesan...

# %%
def preprocess_image(image_path):
    """
    Fungsi untuk melakukan pra-pemrosesan citra tulisan tangan
    """
    try:
        # Baca gambar
        img = cv2.imread(image_path)

        if img is None:
            print(f"Warning: Tidak dapat membaca gambar {image_path}")
            return None, None

        # Konversi ke grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Inversi warna (background hitam, digit putih -> background putih, digit hitam)
        inverted = cv2.bitwise_not(gray)

        # Resize ke 28x28 piksel
        resized = cv2.resize(inverted, (28, 28), interpolation=cv2.INTER_AREA)

        # Normalisasi pixel values ke range [0, 1]
        normalized = resized / 255.0

        # Reshape untuk matching model input (28, 28, 1)
        reshaped = normalized.reshape(1, 28, 28, 1)

        return reshaped, normalized

    except Exception as e:
        print(f"Error processing {image_path}: {str(e)}")
        return None, None

# %%
def load_handwritten_dataset(base_dir):
    """
    Memuat dataset tulisan tangan dari folder
    """
    images = []
    labels = []
    image_paths = []
    original_images = []  # Untuk menyimpan gambar asli yang sudah diproses

    # Loop melalui setiap folder (0, 1, 9)
    for digit in ['0', '1', '9']:
        digit_dir = os.path.join(base_dir, digit)

        if os.path.exists(digit_dir):
            # Loop melalui setiap file dalam folder
            for filename in sorted(os.listdir(digit_dir)):
                if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
                    image_path = os.path.join(digit_dir, filename)

                    # Pra-pemrosesan gambar
                    processed_img, original_processed = preprocess_image(image_path)

                    if processed_img is not None:
                        images.append(processed_img)
                        labels.append(int(digit))
                        image_paths.append(image_path)
                        original_images.append(original_processed)

    return images, labels, image_paths, original_images

# %%
# Memuat dataset tulisan tangan
print("Memuat dan memproses gambar tulisan tangan...")
handwritten_images, handwritten_labels, image_paths, original_processed_images = load_handwritten_dataset(base_dir)
# Out:
# Memuat dan memproses gambar tulisan tangan...

# %%
print(f"Total gambar yang berhasil diproses: {len(handwritten_images)}")
print(f"Distribusi label: {np.unique(handwritten_labels, return_counts=True)}")
# Out:
# Total gambar yang berhasil diproses: 30
# Distribusi label: (array([0, 1, 9]), array([10, 10, 10]))

# %%
# Visualisasi contoh citra sebelum dan setelah pra-pemrosesan
print("=== VISUALISASI CONTOH CITRA SETELAH PRA-PEMROSESAN ===")

# Tampilkan 6 contoh gambar
plt.figure(figsize=(15, 10))

for i in range(6):
    if i < len(handwritten_images):
        # Gambar asli (sebelum pra-pemrosesan)
        img_original = cv2.imread(image_paths[i])
        img_original_rgb = cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB)

        # Gambar setelah pra-pemrosesan
        img_processed = original_processed_images[i]

        # Plot gambar asli
        plt.subplot(3, 4, 2*i + 1)
        plt.imshow(img_original_rgb)
        plt.title(f'Asli: {handwritten_labels[i]}\n{os.path.basename(image_paths[i])}')
        plt.axis('off')

        # Plot gambar setelah pra-pemrosesan
        plt.subplot(3, 4, 2*i + 2)
        plt.imshow(img_processed, cmap='gray')
        plt.title(f'Setelah Pra-proses\n28x28, Grayscale')
        plt.axis('off')

plt.tight_layout()
plt.show()

# Visualisasi grid semua gambar setelah pra-pemrosesan
print("\n=== SEMUA GAMBAR SETELAH PRA-PEMROSESAN ===")
plt.figure(figsize=(20, 6))

for idx, (img_processed, label) in enumerate(zip(original_processed_images, handwritten_labels)):
    plt.subplot(3, 10, idx + 1)
    plt.imshow(img_processed, cmap='gray')
    plt.title(f'{label}', fontsize=10)
    plt.axis('off')

plt.suptitle('Semua Gambar Tulisan Tangan Setelah Pra-pemrosesan', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# === VISUALISASI CONTOH CITRA SETELAH PRA-PEMROSESAN ===
# === SEMUA GAMBAR SETELAH PRA-PEMROSESAN ===

# %%
# Cek jika model sudah ada, jika tidak buat model baru
try:
    print("Mencoba memuat model CNN yang sudah ditrain...")
    model = keras.models.load_model('mnist_cnn_model.h5')
    print("Model berhasil dimuat!")
except:
    print("Model tidak ditemukan. Melatih model CNN baru...")

    # Load dataset MNIST
    (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

    # Preprocess data
    x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
    x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

    # Buat model CNN
    model = keras.Sequential([
        keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Conv2D(64, (3, 3), activation='relu'),
        keras.layers.MaxPooling2D((2, 2)),
        keras.layers.Conv2D(64, (3, 3), activation='relu'),
        keras.layers.Flatten(),
        keras.layers.Dense(64, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, activation='softmax')
    ])

    # Compile model
    model.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

    # Train model
    history = model.fit(x_train, y_train,
                       epochs=5,
                       batch_size=128,
                       validation_split=0.1,
                       verbose=1)

    # Simpan model
    model.save('mnist_cnn_model.h5')
    print("Model baru berhasil dilatih dan disimpan!")

# Tampilkan summary model
model.summary()
# Out:
# Mencoba memuat model CNN yang sudah ditrain...
# Model tidak ditemukan. Melatih model CNN baru...
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.7023 - loss: 0.8963 - val_accuracy: 0.9803 - val_loss: 0.0636
# Epoch 2/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 46s 109ms/step - accuracy: 0.9570 - loss: 0.1516 - val_accuracy: 0.9870 - val_loss: 0.0433
# Epoch 3/5
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 83s 113ms/step - accuracy: 0.9692 - loss: 0.1022 - val_accuracy: 0.9880 - val_loss: 0.0385
# Epoch 4/5
# ...

# %%
handwritten_images_array = np.vstack(handwritten_images)
predictions = model.predict(handwritten_images_array)
predictions = np.argmax(predictions, axis=1)

true_labels = np.array(handwritten_labels)

# Menghitung akurasi
accuracy = accuracy_score(true_labels, predictions)
print(f"\n=== HASIL EVALUASI ===")
print(f"Akurasi Model pada Tulisan Tangan Sendiri: {accuracy:.4f} ({accuracy * 100:.2f}%)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
#
# === HASIL EVALUASI ===
# Akurasi Model pada Tulisan Tangan Sendiri: 0.3667 (36.67%)

# %%
# Menampilkan hasil prediksi untuk setiap citra dalam bentuk tabel
print("\n=== DETAIL HASIL PREDIKSI SETIAP CITRA ===")
print("\n" + "="*80)
print(f"{'No.':<3} {'File':<20} {'Label True':<10} {'Prediksi':<10} {'Confidence':<12} {'Status':<10}")
print("="*80)
# Out:
# === DETAIL HASIL PREDIKSI SETIAP CITRA ===
#
# ...
# No. File                 Label True Prediksi   Confidence   Status
# ...

# %%
# Menampilkan hasil prediksi untuk setiap citra dalam bentuk tabel
print("\n=== DETAIL HASIL PREDIKSI SETIAP CITRA ===")
print("\n" + "="*80)
print(f"{'No.':<3} {'File':<20} {'Label True':<10} {'Prediksi':<10} {'Confidence':<12} {'Status':<10}")
print("="*80)

# Mendapatkan probabilitas prediksi untuk setiap kelas
raw_predictions = model.predict(handwritten_images_array)
# Mendapatkan confidence (probabilitas tertinggi dari kelas yang diprediksi)
prediction_confidences = np.max(raw_predictions, axis=1)

correct_predictions = 0
total_predictions = len(handwritten_images)

for i, (true_label, pred_label, confidence, img_path) in enumerate(zip(true_labels, predictions, prediction_confidences, image_paths)):
    # Ekstrak nama file
    file_name = os.path.basename(img_path)
    folder_name = os.path.basename(os.path.dirname(img_path))

    status = "BENAR" if true_label == pred_label else "SALAH"
    if true_label == pred_label:
        correct_predictions += 1

    print(f"{i+1:<3} {file_name:<20} {true_label:<10} {pred_label:<10} {confidence:.4f}      {status:<10}")

print("="*80)
print(f"Total Prediksi Benar: {correct_predictions}/{total_predictions}")
print(f"Akurasi: {accuracy:.4f} ({accuracy * 100:.2f}%)")
# Out:
# === DETAIL HASIL PREDIKSI SETIAP CITRA ===
#
# ...
# No. File                 Label True Prediksi   Confidence   Status
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1   digit0_1.png         0          1          0.4770      SALAH
# 2   digit0_10.png        0          1          0.4634      SALAH
# 3   digit0_2.png         0          1          0.4036      SALAH
# 4   digit0_3.png         0          0          0.3517      BENAR
# 5   digit0_4.png         0          1          0.4755      SALAH
# 6   digit0_5.png         0          1          0.4595      SALAH
# 7   digit0_6.png         0          1          0.4400      SALAH
# 8   digit0_7.png         0          1          0.3942      SALAH
# 9   digit0_8.png         0          1          0.4884      SALAH
# 10  digit0_9.png         0          1          0.5271      SALAH
# 11  digit1_1.png         1          1          0.6913      BENAR
# 12  digit1_10.png        1          1          0.7049      BENAR
# ...

# %%
# Visualisasi hasil prediksi dengan warna berbeda untuk benar/salah
print("\n=== VISUALISASI HASIL PREDIKSI ===")

# Pisahkan prediksi benar dan salah
correct_indices = [i for i in range(len(predictions)) if predictions[i] == true_labels[i]]
wrong_indices = [i for i in range(len(predictions)) if predictions[i] != true_labels[i]]

print(f"Jumlah prediksi benar: {len(correct_indices)}")
print(f"Jumlah prediksi salah: {len(wrong_indices)}")

# Tampilkan semua gambar dengan marking benar/salah
plt.figure(figsize=(20, 12))

for idx, (img_processed, true_label, pred_label) in enumerate(zip(original_processed_images, true_labels, predictions)):
    plt.subplot(5, 6, idx + 1)

    # Gunakan warna biru untuk benar, merah untuk salah
    cmap = 'viridis' if true_label == pred_label else 'hot'
    plt.imshow(img_processed, cmap=cmap)

    status = "✓" if true_label == pred_label else "✗"
    title_color = 'blue' if true_label == pred_label else 'red'

    plt.title(f'True: {true_label} Pred: {pred_label} {status}',
              color=title_color, fontsize=10)
    plt.axis('off')

plt.suptitle('Hasil Prediksi Semua Gambar (biru: Benar, Merah: Salah)', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# === VISUALISASI HASIL PREDIKSI ===
# Jumlah prediksi benar: 11
# Jumlah prediksi salah: 19

# %%
# Confusion Matrix
print("\n=== CONFUSION MATRIX ===")

cm = confusion_matrix(true_labels, predictions, labels=[0, 1, 9])

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds',
            xticklabels=['0', '1', '9'],
            yticklabels=['0', '1', '9'])
plt.title('Konfusion Matrix | Eval Tulisan Tangan Sendiri')
plt.xlabel('Prediksi Label')
plt.ylabel('True Label')
plt.show()

# Classification report
print("\n=== KLASIFIKASI REPORT ===")
print(classification_report(true_labels, predictions, labels=[0, 1, 9], target_names=['0', '1', '9']))

# Analisis per digit
print("\n=== ANALISIS PERDIGIT ===")
for digit in [0, 1, 9]:
    digit_indices = [i for i, label in enumerate(true_labels) if label == digit]

    if digit_indices:
        digit_predictions = predictions[digit_indices]
        digit_accuracy = accuracy_score([digit] * len(digit_indices), digit_predictions)

        correct = sum(1 for pred in digit_predictions if pred == digit)

        print(f"\nDigit {digit}:")
        print(f"  - Jumlah sampel: {len(digit_indices)}")
        print(f"  - Akurasi: {digit_accuracy:.4f} ({digit_accuracy * 100:.2f}%)")
        print(f"  - Prediksi benar: {correct}/{len(digit_indices)}")

        # Tampilkan distribusi prediksi yang salah
        wrong_predictions = [pred for pred in digit_predictions if pred != digit]
        if wrong_predictions:
            unique_wrong, counts = np.unique(wrong_predictions, return_counts=True)
            print(f"  - Prediksi salah: {dict(zip(unique_wrong, counts))}")
# Out:
# === CONFUSION MATRIX ===
# === KLASIFIKASI REPORT ===
#               precision    recall  f1-score   support
#
#            0       1.00      0.10      0.18        10
#            1       0.34      1.00      0.51        10
#            9       0.00      0.00      0.00        10
#
#     accuracy                           0.37        30
#    macro avg       0.45      0.37      0.23        30
# weighted avg       0.45      0.37      0.23        30
#
#
# === ANALISIS PERDIGIT ===
#
# Digit 0:
#   - Jumlah sampel: 10
#   - Akurasi: 0.1000 (10.00%)
#   - Prediksi benar: 1/10
#   - Prediksi salah: {np.int64(1): np.int64(9)}
#
# Digit 1:
#   - Jumlah sampel: 10
#   - Akurasi: 1.0000 (100.00%)
#   - Prediksi benar: 10/10
#
# Digit 9:
#   - Jumlah sampel: 10
#   - Akurasi: 0.0000 (0.00%)
#   - Prediksi benar: 0/10
#   - Prediksi salah: {np.int64(1): np.int64(10)}
# ...

# %%
# Analisis confidence score
print("\n=== ANALISIS KONFIDEN SKOR ===")

plt.figure(figsize=(12, 6))

# Plot confidence untuk prediksi benar dan salah
colors = ['blue' if true == pred else 'red' for true, pred in zip(true_labels, predictions)]

plt.subplot(1, 2, 1)
plt.scatter(range(len(prediction_confidences)), prediction_confidences, c=colors, alpha=0.7)
plt.axhline(y=0.9, color='red', linestyle='--', alpha=0.7, label='Threshold 0.9')
plt.axhline(y=0.7, color='pink', linestyle='--', alpha=0.7, label='Threshold 0.7')
plt.xlabel('Sample Index')
plt.ylabel('konfiden Skor')
plt.title('Konfiden Skor untuk Setiap Prediksi')
plt.legend()
plt.grid(True, alpha=0.3)

# Histogram confidence
plt.subplot(1, 2, 2)
correct_confidences = [conf for i, conf in enumerate(prediction_confidences) if true_labels[i] == predictions[i]]
wrong_confidences = [conf for i, conf in enumerate(prediction_confidences) if true_labels[i] != predictions[i]]

plt.hist(correct_confidences, bins=10, alpha=0.7, label='Benar', color='blue')
plt.hist(wrong_confidences, bins=10, alpha=0.7, label='Salah', color='red')
plt.xlabel('Konfiden Skor')
plt.ylabel('Frekuensi')
plt.title('Distribusi Konfiden Skor')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Statistik confidence
print(f"Rata-rata konfiden prediksi benar: {np.mean(correct_confidences):.4f}")
print(f"Rata-rata konfiden prediksi salah: {np.mean(wrong_confidences):.4f}")
# Out:
# === ANALISIS KONFIDEN SKOR ===
# Rata-rata konfiden prediksi benar: 0.6598
# Rata-rata konfiden prediksi salah: 0.5384

# %%
# Ringkasan akhir evaluasi
print("\n" + "="*60)
print("RINGKASAN EVALUASI MODEL CNN PADA TULISAN TANGAN SENDIRI")
print("="*60)

print(f"\n1. DATA EVALUASI:")
print(f"   - Total gambar: {len(handwritten_images)}")
print(f"   - Digit 0: {sum(1 for label in true_labels if label == 0)} gambar")
print(f"   - Digit 1: {sum(1 for label in true_labels if label == 1)} gambar")
print(f"   - Digit 9: {sum(1 for label in true_labels if label == 9)} gambar")

print(f"\n2. HASIL PREDIKSI:")
print(f"   - Akurasi keseluruhan: {accuracy:.4f} ({accuracy * 100:.2f}%)")
print(f"   - Prediksi benar: {correct_predictions}/{total_predictions}")
# Out:
# ...
# RINGKASAN EVALUASI MODEL CNN PADA TULISAN TANGAN SENDIRI
# ...
#
# 1. DATA EVALUASI:
#    - Total gambar: 30
#    - Digit 0: 10 gambar
#    - Digit 1: 10 gambar
#    - Digit 9: 10 gambar
#
# 2. HASIL PREDIKSI:
#    - Akurasi keseluruhan: 0.3667 (36.67%)
#    - Prediksi benar: 11/30

# %%
# Evaluasi performa
if accuracy >= 0.9:
    performance = "SANGAT BAIK"
    recommendation = "Model sangat handal untuk mengenali tulisan tangan Anda"
elif accuracy >= 0.8:
    performance = "BAIK"
    recommendation = "Model cukup handal, dapat digunakan dengan baik"
elif accuracy >= 0.7:
    performance = "CUKUP"
    recommendation = "Model perlu sedikit perbaikan pada data training"
elif accuracy >= 0.6:
    performance = "KURANG"
    recommendation = "Disarankan untuk retraining model dengan data yang lebih beragam"
else:
    performance = "BURUK"
    recommendation = "Perlu evaluasi ulang model dan data training"

print(f"\n3. TINGKAT PERFORMA: {performance}")
print(f"\n4. REKOMENDASI:")
print(f"   - {recommendation}")

print(f"\n5. FAKTOR YANG MEMPENGARUHI:")
print(f"   - Gaya penulisan personal")
print(f"   - Kualitas gambar yang diupload")
print(f"   - Variasi bentuk digit yang ditulis")
print(f"   - Kemiripan antar digit (contoh: 3 vs 8, 7 vs 1)")

print(f"\n6. SUGESTI PERBAIKAN:")
if len(wrong_indices) > 0:
    print("   - Analisis gambar yang salah prediksi:")
    for idx in wrong_indices:
        print(f"     * {os.path.basename(image_paths[idx])}: True={true_labels[idx]}, Pred={predictions[idx]}")
# Out:
# 3. TINGKAT PERFORMA: BURUK
#
# 4. REKOMENDASI:
#    - Perlu evaluasi ulang model dan data training
#
# 5. FAKTOR YANG MEMPENGARUHI:
#    - Gaya penulisan personal
#    - Kualitas gambar yang diupload
#    - Variasi bentuk digit yang ditulis
#    - Kemiripan antar digit (contoh: 3 vs 8, 7 vs 1)
#
# 6. SUGESTI PERBAIKAN:
#    - Analisis gambar yang salah prediksi:
#      * digit0_1.png: True=0, Pred=1
#      * digit0_10.png: True=0, Pred=1
#      * digit0_2.png: True=0, Pred=1
#      * digit0_4.png: True=0, Pred=1
#      * digit0_5.png: True=0, Pred=1
#      * digit0_6.png: True=0, Pred=1
#      * digit0_7.png: True=0, Pred=1
#      * digit0_8.png: True=0, Pred=1
#      * digit0_9.png: True=0, Pred=1
#      * digit9_1.png: True=9, Pred=1
#      * digit9_10.png: True=9, Pred=1
#      * digit9_2.png: True=9, Pred=1
#      * digit9_3.png: True=9, Pred=1
#      * digit9_4.png: True=9, Pred=1
#      * digit9_5.png: True=9, Pred=1
#      * digit9_6.png: True=9, Pred=1
# ...

# %%
# Simpan hasil evaluasi ke file
print("\n=== MENYIMPAN HASIL EVALUASI ===")

results_dir = 'evaluation_results'
os.makedirs(results_dir, exist_ok=True)

# Simpan summary hasil
with open(f'{results_dir}/evaluation_summary.txt', 'w') as f:
    f.write("HASIL EVALUASI MODEL CNN PADA TULISAN TANGAN SENDIRI\n")
    f.write("="*50 + "\n\n")
    f.write(f"Tanggal Evaluasi: {np.datetime64('today')}\n")
    f.write(f"NIM: 202332037\n")
    f.write(f"Digit yang diuji: 0, 3, 7\n\n")
    f.write(f"Total Gambar: {len(handwritten_images)}\n")
    f.write(f"Akurasi: {accuracy:.4f} ({accuracy * 100:.2f}%)\n")
    f.write(f"Prediksi Benar: {correct_predictions}/{total_predictions}\n\n")

    f.write("Detail Per Digit:\n")
    for digit in [0, 3, 7]:
        digit_count = sum(1 for label in true_labels if label == digit)
        digit_correct = sum(1 for i, label in enumerate(true_labels) if label == digit and predictions[i] == digit)
        digit_accuracy = digit_correct / digit_count if digit_count > 0 else 0
        f.write(f"  Digit {digit}: {digit_correct}/{digit_count} ({digit_accuracy:.4f})\n")

print("Hasil evaluasi sudah disimpan di folder 'evaluation_results'")
print("Evaluasi sudah selesai, yeayy!")
print("TERIMAKASIH, MATUR NUWUN!")
# Out:
# === MENYIMPAN HASIL EVALUASI ===
# Hasil evaluasi sudah disimpan di folder 'evaluation_results'
# Evaluasi sudah selesai, yeayy!
# TERIMAKASIH, MATUR NUWUN!
